# %% [markdown]
# # Baca dataset

# %%
from dataset import isic_dataset
import os
import pandas as pd
import cv2
import sys
import matplotlib.pyplot as pyplot
import numpy as np

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Resize

# %% [markdown]
# ## Implementasi Hair Removal

# %% [markdown]
# ## Data Augmentasi
