# %%
import os
import numpy as np
import PIL.Image
import pandas as pd
import cv2
from models import UNet
from dataset import ISICDataset
from preprocessing import laplacian_hr, resize_image, bothat_hr

# %%
input_path = 'dataset/training/images'
img_path = os.path.join(input_path, 'ISIC_0000148.jpg')
resized = resize_image(img_path)
img, dilated = laplacian_hr(resized, True)

# %%
input_path = 'dataset/training/images'
img_path = os.path.join(input_path, 'ISIC_0000148.jpg')
resized = resize_image(img_path)
img, dilated = bothat_hr(resized, True)
